# %%
import pandas as pd

# %%
df = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB-2021_Table_13A.1.csv')

# %%
df.head()
# Out:
#   Sl. No.           State/UT  2019  2020  2021  Chargesheeting Rate (2021)
# 0       1     Andhra Pradesh   9.0     0     0                       100.0
# 1       2  Arunachal Pradesh   0.0     0     0                         NaN
# 2       3              Assam  15.0     4     0                         NaN
# 3       4              Bihar   1.0     0     0                         NaN
# 4       5       Chhattisgarh   0.0     1     0                         NaN

# %%
df2 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB-2021_Table_13A.2.csv')

# %%
df2.head()
# Out:
#   Sl. No Col. (1) Category                       Crime Head - Col. (2)  \
# 0               1      IPC                                      Murder
# 1               2      IPC   Culpable Homicide not amounting to Murder
# 2               3      IPC  Attempt to Commit Murder/Culpable Homicide
# 3               4      IPC                                 Simple Hurt
# 4               5      IPC                               Grievous Hurt
#
#    Cases of Crimes committed against - Foreign Tourists - Col. (3)  \
# 0                                                  5
# 1                                                  0
# 2                                                  2
# 3                                                  5
# 4                                                  0
#
#    Cases of Crimes committed against - Other Foreigners - Col. (4)  \
# 0                                                  4
# 1                                                  0
# ...

# %%
df3 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB-2021_Table_13A.4.csv')

# %%
df3.head()
# Out:
#   Sl. No. Col. (1)                         Crime Head Col. (2)  \
# 0              1.1                                      Murder
# 1              1.2   Culpable Homicide not amounting to Murder
# 2              1.3  Attempt to Commit Murder/Culpable Homicide
# 3              1.4                                 Simple Hurt
# 4              1.5                               Grievous Hurt
#
#    Cases Pending Trial from the Previous Year - Col. (3)  \
# 0                                                 29
# 1                                                  3
# 2                                                 15
# 3                                                 13
# 4                                                  6
#
#    Cases Sent for Trial during the year - Col. (4)  \
# 0                                                5
# 1                                                1
# 2                                                1
# ...

# %%
df4 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII-2019_Table_13A.1.csv')

# %%
df4.head()
# Out:
#   Category          State/UT   2017  2018  2019  \
# 0    State     Andhra Pradesh     3     3     9
# 1    State  Arunachal Pradesh     0     0     0
# 2    State              Assam     2     7    15
# 3    State              Bihar     9     0     1
# 4    State       Chhattisgarh     1     0     0
#
#    % of State Share to Total Crimes - 2019
# 0                                      2.2
# 1                                      0.0
# 2                                      3.7
# 3                                      0.2
# 4                                      0.0

# %%
df5 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII-2019_Table_13A.2.csv')  
df5.head()
# Out:
#   Category                                  Crime Head  \
# 0      IPC                                      Murder
# 1      IPC   Culpable Homicide not amounting to Murder
# 2      IPC  Attempt to Commit Murder/Culpable Homicide
# 3      IPC                                 Simple Hurt
# 4      IPC                               Grievous Hurt
#
#    Cases of Crimes Committed against - Foreign Tourists  \
# 0                                                  9
# 1                                                  1
# 2                                                  5
# 3                                                  5
# 4                                                  1
#
#    Cases of Crimes Committed against - Other  Foreigners  \
# 0                                                  4
# 1                                                  0
# 2                                                  4
# 3                                                  9
# ...

# %%
df6 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII-2019_Table_13A.3.csv') 
df6.head()
# Out:
#   S.No.                                  Crime Head  \
# 0   1.1                                      Murder
# 1   1.2   Culpable Homicide not amounting to Murder
# 2   1.3  Attempt to Commit Murder/Culpable Homicide
# 3   1.4                                 Simple Hurt
# 4   1.5                               Grievous Hurt
#
#    Cases Pending Investigation from Previous Year  \
# 0                                               2
# 1                                               1
# 2                                               0
# 3                                               3
# 4                                               3
#
#    Cases Reported during the year  Cases Reopened for Investigation  \
# 0                               9                                 0
# 1                               1                                 0
# 2                               5                                 0
# 3                               5                                 0
# ...

# %%
df7 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII-2019_Table_13A.4.csv')  
df7.head()
# Out:
#   S. No.                                  Crime Head  \
# 0    1.1                                      Murder
# 1    1.2   Culpable Homicide not amounting to Murder
# 2    1.3  Attempt to Commit Murder/Culpable Homicide
# 3    1.4                                 Simple Hurt
# 4    1.5                               Grievous Hurt
#
#    Cases Pending Trial from the Previous Year  \
# 0                                          22
# 1                                           3
# 2                                           9
# 3                                           8
# 4                                           5
#
#    Cases Sent for Trial during the year  Total Cases for Trial (Col.3+ Col.4)  \
# 0                                     6                                    28
# 1                                     1                                     4
# 2                                     5                                    14
# ...

# %%
df7 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII-2020_Table.No-13A.1.csv') 
df7.head()
# Out:
#   Si. No (Col. 1) Category   State/UT (Col. 2)  2018 - (Col. 3)  \
# 0               1     State     Andhra Pradesh              3.0
# 1               2     State  Arunachal Pradesh              0.0
# 2               3     State              Assam              7.0
# 3               4     State              Bihar              0.0
# 4               5     State       Chhattisgarh              0.0
#
#   Note of 2018 - (Col. 3)  2019 - (Col. 4) Note of 2019 - (Col. 4)  \
# 0                     NaN              9.0                     NaN
# 1                     NaN              0.0                     NaN
# 2                     NaN             15.0                     NaN
# 3                     NaN              1.0                     NaN
# 4                     NaN              0.0                     NaN
#
#    2020 - (Col. 5)  Chargesheeting Rate (2020) - (Col. 6)
# 0                0                                    0.0
# 1                0                                    NaN
# ...

# %%
df8 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII-2020_Table.No-13A.2.csv') 
df8.head()
# Out:
#   Si. No. (Col. 1) Category                         Crime Head (Col. 2)  \
# 0                1      IPC                                      Murder
# 1                2      IPC   Culpable Homicide not amounting to Murder
# 2                3      IPC  Attempt to Commit Murder/Culpable Homicide
# 3                4      IPC                                 Simple Hurt
# 4                5      IPC                               Grievous Hurt
#
#    Cases of Crimes Committed against - Foreign Tourists - (Col. 3)  \
# 0                                                  3
# 1                                                  0
# 2                                                  6
# 3                                                  4
# 4                                                  0
#
#    Cases of Crimes Committed against - Other Foreigners - (Col. 4)  \
# 0                                                  4
# 1                                                  1
# ...

# %%
df9 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII-2020_Table.No-13A.3.csv')  
df9.head()
# Out:
#   Si. No. (Col. 1)                         Crime Head (Col. 2)  \
# 0              1.1                                      Murder
# 1              1.2   Culpable Homicide not amounting to Murder
# 2              1.3  Attempt to Commit Murder/Culpable Homicide
# 3              1.4                                 Simple Hurt
# 4              1.5                               Grievous Hurt
#
#    Cases Pending Investigation from Previous Year - (Col. 3)  \
# 0                                                  5
# 1                                                  1
# 2                                                  0
# 3                                                  3
# 4                                                  2
#
#    Cases Reported during the year - (Col. 4)  \
# 0                                          3
# 1                                          0
# 2                                          6
# 3                                          4
# ...

# %%
df10 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII-2020_Table.No-13A.4.csv')  
df10.head()
# Out:
#   Si. No. (Col. 1)                         Crime Head (Col. 2)  \
# 0              1.1                                      Murder
# 1              1.2   Culpable Homicide not amounting to Murder
# 2              1.3  Attempt to Commit Murder/Culpable Homicide
# 3              1.4                                 Simple Hurt
# 4              1.5                               Grievous Hurt
#
#    Cases Pending Trial from the Previous Year - (Col. 3)  \
# 0                                                 27
# 1                                                  3
# 2                                                 13
# 3                                                 12
# 4                                                  6
#
#    Cases Sent for Trial during the year - (Col. 4)  \
# 0                                                3
# 1                                                0
# 2                                                5
# ...

# %%
df11 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII_2017_State_Table-13A.1.csv') 
df11.head()
# Out:
#   S. No. Category           State/UT  2015  2016  2017  \
# 0      1    State     Andhra Pradesh     1     5     3
# 1      2    State  Arunachal Pradesh     0     0     0
# 2      3    State              Assam     0     0     2
# 3      4    State              Bihar     0    10     9
# 4      5    State       Chhattisgarh     0     0     1
#
#    % of State Share to Total Crimes - 2017
# 0                                      0.6
# 1                                      0.0
# 2                                      0.4
# 3                                      1.8
# 4                                      0.2

# %%
df12 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII_2017_State_Table-13A.2.csv') 
df12.head()
# Out:
#   S. No. (Col.1) Category (Col.2)                          Crime Head (Col.3)  \
# 0              1           A. IPC                                      Murder
# 1              2           A. IPC   Culpable Homicide not amounting to Murder
# 2              3           A. IPC  Attempt to Commit Murder/Culpable Homicide
# 3              4           A. IPC                                 Simple Hurt
# 4              5           A. IPC                               Grievous Hurt
#
#    Cases of Crimes Committed against - Foreign Tourists (Col.4)  \
# 0                                                  5
# 1                                                  2
# 2                                                  1
# 3                                                  2
# 4                                                  4
#
#    Cases of Crimes Committed against - Other Foreigners (Col.5)  \
# 0                                                  8
# ...

# %%
df13 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII_2017_State_Table-13A.3.csv') 
df13.head()
# Out:
#   S. No (Col.1)                         Category (Col.2)  \
# 0           1.1  Total Crimes against Tourist Foreigners
# 1           1.2  Total Crimes against Tourist Foreigners
# 2           1.3  Total Crimes against Tourist Foreigners
# 3           1.4  Total Crimes against Tourist Foreigners
# 4           1.5  Total Crimes against Tourist Foreigners
#
#                            Crime Head (Col.3)  \
# 0                                      Murder
# 1   Culpable Homicide not amounting to Murder
# 2  Attempt to Commit Murder/Culpable Homicide
# 3                                 Simple Hurt
# 4                               Grievous Hurt
#
#    Cases Pending Investigation from Previous Year (Col.4)  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  2
#
# ...

# %%
df14 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII_2017_State_Table-13A.4.csv') 
df14.head()
# Out:
#   S. No. (Col.1)                         Category (Col.2)  \
# 0            1.1  Total Crimes against Tourist Foreigners
# 1            1.2  Total Crimes against Tourist Foreigners
# 2            1.3  Total Crimes against Tourist Foreigners
# 3            1.4  Total Crimes against Tourist Foreigners
# 4            1.5  Total Crimes against Tourist Foreigners
#
#                            Crime Head (Col.3)  \
# 0                                      Murder
# 1   Culpable Homicide not amounting to Murder
# 2  Attempt to Commit Murder/Culpable Homicide
# 3                                 Simple Hurt
# 4                               Grievous Hurt
#
#    Cases Pending Trial from the Previous Year (Col.4)  \
# 0                                                 14
# 1                                                  1
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
# ...

# %%
df15 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII_2018_State_Table13A.1.csv')  
df15.head()
# Out:
#   S. No. Category           State/UT  2016  2017  2018  \
# 0      1    State     Andhra Pradesh     5     3     3
# 1      2    State  Arunachal Pradesh     0     0     0
# 2      3    State              Assam     0     2     7
# 3      4    State              Bihar    10     9     0
# 4      5    State       Chhattisgarh     0     1     0
#
#    % of State Share to Total Crimes - 2018
# 0                                      0.6
# 1                                      0.0
# 2                                      1.4
# 3                                      0.0
# 4                                      0.0

# %%
df16 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII_2018_State_Table13A.2.csv') 
df16.head()
# Out:
#   S. No. (Col.1) Category (Col.2)                          Crime Head (Col.3)  \
# 0              1           A. IPC                                      Murder
# 1              2           A. IPC   Culpable Homicide not amounting to Murder
# 2              3           A. IPC  Attempt to Commit Murder/Culpable Homicide
# 3              4           A. IPC                                 Simple Hurt
# 4              5           A. IPC                               Grievous Hurt
#
#    Cases of Crimes Committed against - Foreign Tourists (Col.4)  \
# 0                                                  8
# 1                                                  1
# 2                                                  2
# 3                                                  7
# 4                                                  0
#
#    Cases of Crimes Committed against - Other Foreigners (Col.5)  \
# 0                                                  3
# ...

# %%
df17 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII_2018_State_Table13A.3.csv')  
df17.head()
# Out:
#   S. No (Col.1)                   Category (Col.2)  \
# 0           1.1  Crimes against Tourist Foreigners
# 1           1.2  Crimes against Tourist Foreigners
# 2           1.3  Crimes against Tourist Foreigners
# 3           1.4  Crimes against Tourist Foreigners
# 4           1.5  Crimes against Tourist Foreigners
#
#                            Crime Head (Col.3)  \
# 0                                      Murder
# 1   Culpable Homicide not amounting to Murder
# 2  Attempt to Commit Murder/Culpable Homicide
# 3                                 Simple Hurt
# 4                               Grievous Hurt
#
#    Cases Pending Investigation from Previous Year (Col.4)  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  3
#
# ...

# %%
df18 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_CII_2018_State_Table13A.4.csv') 
df18.head()
# Out:
#   S. No. (Col.1)                   Category (Col.2)  \
# 0            1.1  Crimes against Tourist Foreigners
# 1            1.2  Crimes against Tourist Foreigners
# 2            1.3  Crimes against Tourist Foreigners
# 3            1.4  Crimes against Tourist Foreigners
# 4            1.5  Crimes against Tourist Foreigners
#
#                            Crime Head (Col.3)  \
# 0                                      Murder
# 1   Culpable Homicide not amounting to Murder
# 2  Attempt to Commit Murder/Culpable Homicide
# 3                                 Simple Hurt
# 4                               Grievous Hurt
#
#    Cases Pending Trial from the Previous Year (Col.4)  \
# 0                                                 19
# 1                                                  3
# 2                                                  5
# 3                                                  5
# 4                                                  5
#
# ...

# %%
df19 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_Table_13A.2.csv')  
df19.head()
# Out:
#   Sl. No. - Col. (1)                       Crime Head - Col. (2)  \
# 0                  1                                      Murder
# 1                  2   Culpable Homicide not amounting to Murder
# 2                  3  Attempt to Commit Murder/Culpable Homicide
# 3                  4                                 Simple Hurt
# 4                  5                               Grievous Hurt
#
#    Cases of Crimes committed against - Foreign Tourists - Col. (3)  \
# 0                                                  5
# 1                                                  0
# 2                                                  2
# 3                                                  3
# 4                                                  0
#
#    Cases of Crimes committed against - Other Foreigners - Col. (4)  \
# 0                                                  9
# 1                                                  0
# 2                                                  1
# ...

# %%
df20 = pd.read_csv('/home/sanjay/Downloads/dataset/NCRB_Table_13A.3.csv') 
df20.head()
# Out:
#   Sl. No. - Col. (1)                       Crime Head - Col. (2)  \
# 0                1.1                                      Murder
# 1                1.2   Culpable Homicide not amounting to Murder
# 2                1.3  Attempt to Commit Murder/Culpable Homicide
# 3                1.4                                 Simple Hurt
# 4                1.5                               Grievous Hurt
#
#    Cases Pending Investigation from Previous Year - Col. (3)  \
# 0                                                  4
# 1                                                  0
# 2                                                  1
# 3                                                  9
# 4                                                  1
#
#    Cases Reported during the year - Col. (4)  \
# 0                                          5
# 1                                          0
# 2                                          2
# 3                                          3
# ...

# %%
df21 = pd.read_csv('/home/sanjay/Downloads/dataset/Table_13A.1_2016.csv') 
df21.head()
# Out:
#   S. No. Category           State/UT  Year - 2014  Year - 2015  Year - 2016  \
# 0      1    State     Andhra Pradesh            5            1            5
# 1      2    State  Arunachal Pradesh            0            0            0
# 2      3    State              Assam            0            0            0
# 3      4    State              Bihar           13            0           10
# 4      5    State       Chhattisgarh            0            0            0
#
#    Percentage of State Share to Total Crimes
# 0                                        1.3
# 1                                        0.0
# 2                                        0.0
# 3                                        2.6
# 4                                        0.0

# %%
df22 = pd.read_csv('/home/sanjay/Downloads/dataset/Table_13A.2_2016.csv') 
df22.head(
# Out:
#   Category (Col.1)                          CrimeHead (Col.2)  \
# 0              IPC                                     Murder
# 1              IPC  Culpable Homicide not Amounting to Murder
# 2              IPC                   Attempt to Commit Murder
# 3              IPC        Attempt to Commit Culpable Homicide
# 4              IPC                              Grievous Hurt
#
#    Cases of Crimes Committed against - Foreign Tourists (Col.3)  \
# 0                                                  6
# 1                                                  2
# 2                                                  0
# 3                                                  0
# 4                                                  2
#
#    Cases of Crimes Committed against - Other Foreigners (Col.4)  \
# 0                                                  6
# 1                                                  0
# 2                                                  1
# ...

# %%
df23 = pd.read_csv('/home/sanjay/Downloads/dataset/Table_13A.3_2016.csv') 
df23.head()
# Out:
#         Category (Col.1) Sub-Category (Col.2)  \
# 0  A) Tourist Foreigners          IPC - Cases
# 1  A) Tourist Foreigners          IPC - Cases
# 2  A) Tourist Foreigners          IPC - Cases
# 3  A) Tourist Foreigners          IPC - Cases
# 4  A) Tourist Foreigners          IPC - Cases
#
#                                Crime Head (Col.3)  \
# 0                                     A.1. Murder
# 1  A.2. Culpable Homicide not Amounting to Murder
# 2                   A.3. Attempt to Commit Murder
# 3        A.4. Attempt to Commit Culpable Homicide
# 4                              A.5. Grievous Hurt
#
#    Cases pending investigation from previous year (Col.4)  \
# 0                                                  3
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  4
#
# ...

# %%
df25 = pd.read_csv('/home/sanjay/Downloads/dataset/Table_13A.4_2016.csv')  
df25.head()
# Out:
#                                     Category (Col.1)  \
# 0  A) Crime Against Tourist Foreigners - IPC - Cases
# 1  A) Crime Against Tourist Foreigners - IPC - Cases
# 2  A) Crime Against Tourist Foreigners - IPC - Cases
# 3  A) Crime Against Tourist Foreigners - IPC - Cases
# 4  A) Crime Against Tourist Foreigners - IPC - Cases
#
#                                Crime Head (Col.2)  \
# 0                                     A.1. Murder
# 1  A.2. Culpable Homicide not Amounting to Murder
# 2                   A.3. Attempt to Commit Murder
# 3        A.4. Attempt to Commit Culpable Homicide
# 4                              A.5. Grievous Hurt
#
#    Cases pending investigation from previous year (Col.3)  \
# 0                                                  9
# 1                                                  1
# 2                                                  3
# 3                                                  1
# 4                                                  0
#
# ...

# %%
df26 = pd.read_csv('/home/sanjay/Downloads/dataset/Table_25.2-2015.csv')
df26.head()
# Out:
#    S. No (Col. 1)                                Crime Head (Col. 2)  \
# 0               1                               Murder(Sec. 302 IPC)
# 1               2            Attempt To Commit Murder (Sec. 307 IPC)
# 2               3        C.H. Not Amounting To Murder (Sec. 304 IPC)
# 3               4  Attempt to Commit Culpable Homicide (Sec. 308 ...
# 4               5                                               Rape
#
#    Cases of Crimes Committed against - Foreign Tourists (Col. 3)  \
# 0                                                  4
# 1                                                  0
# 2                                                  0
# 3                                                  2
# 4                                                  7
#
#    Cases of Crimes Committed against - Other than Foreign Tourists (Col. 4)  \
# 0                                                  0
# 1                                                  0
# ...
